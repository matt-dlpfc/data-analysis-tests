# %%
import pandas as pd

# %% [markdown]
# ### Import

# %%
full_df = pd.read_csv("C:/Users/Matteo/Python-projects/data-analysis-tests/data/project_pokemon/pokemon.csv")

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
# assign to a new df object only a subset of relevant columns
df = full_df[[
    'name', 'attack', 'base_total', 'capture_rate',
       'defense', 'hp',
       'percentage_male', 'pokedex_number',
       'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
       'generation', 'is_legendary']]

df.head()

# %% [markdown]
# ### Some EDA

# %%
df.describe()
# ~8.7% of pokemons are legendary! I would have expected way less than that!
# Out:
#            attack  base_total     defense          hp  percentage_male  \
# count  801.000000  801.000000  801.000000  801.000000       703.000000
# mean    77.857678  428.377029   73.008739   68.958801        55.155761
# std     32.158820  119.203577   30.769159   26.576015        20.261623
# min      5.000000  180.000000    5.000000    1.000000         0.000000
# 25%     55.000000  320.000000   50.000000   50.000000        50.000000
# 50%     75.000000  435.000000   70.000000   65.000000        50.000000
# 75%    100.000000  505.000000   90.000000   80.000000        50.000000
# max    185.000000  780.000000  230.000000  255.000000       100.000000
#
#        pokedex_number   sp_attack  sp_defense       speed   weight_kg  \
# count      801.000000  801.000000  801.000000  801.000000  781.000000
# mean       401.000000   71.305868   70.911361   66.334582   61.378105
# std        231.373075   32.353826   27.942501   28.907662  109.354766
# ...

# %%
# distribution of pokemones based on their types (1)
df["type1"].value_counts().plot(kind = "pie", cmap= "tab20c", autopct="%1.1f%%", figsize=(10,8))
# Out:
# <Axes: ylabel='count'>

# %%
# histogram showing distribution of total points(?)
df["base_total"].plot(kind="hist", figsize=(10,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# pie of legendary ones
df["is_legendary"].value_counts().plot(kind = "pie", 
                                       cmap= "tab20c", 
                                       autopct="%1.1f%%", 
                                       figsize=(10,8))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Questions

# %%
# How many Pokemons exist with an Attack value greater than 150?

## get overview
df["attack"].describe()

## filter
df[df["attack"]>150].info() # Answer: 16
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 126 to 797
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16 non-null     object
#  1   attack           16 non-null     int64
#  2   base_total       16 non-null     int64
#  3   capture_rate     16 non-null     object
#  4   defense          16 non-null     int64
#  5   hp               16 non-null     int64
#  6   percentage_male  10 non-null     float64
#  7   pokedex_number   16 non-null     int64
#  8   sp_attack        16 non-null     int64
#  9   sp_defense       16 non-null     int64
#  10  speed            16 non-null     int64
#  11  type1            16 non-null     object
#  12  type2            10 non-null     object
#  13  weight_kg        15 non-null     float64
#  14  generation       16 non-null     int64
#  15  is_legendary     16 non-null     int64
# dtypes: float64(2), int64(10), object(4)
# ...

# %%
# Select all pokemons with a Speed of 10 or less. Store results in dedicated variable.

slow_pokemons_df = df.loc[df["speed"]<=10]

# %%
# How many Pokemons have a Sp. Def value of 25 or less?

df[df["sp_defense"]<=25].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 9 to 663
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             17 non-null     object
#  1   attack           17 non-null     int64
#  2   base_total       17 non-null     int64
#  3   capture_rate     17 non-null     object
#  4   defense          17 non-null     int64
#  5   hp               17 non-null     int64
#  6   percentage_male  17 non-null     float64
#  7   pokedex_number   17 non-null     int64
#  8   sp_attack        17 non-null     int64
#  9   sp_defense       17 non-null     int64
#  10  speed            17 non-null     int64
#  11  type1            17 non-null     object
#  12  type2            6 non-null      object
#  13  weight_kg        17 non-null     float64
#  14  generation       17 non-null     int64
#  15  is_legendary     17 non-null     int64
# dtypes: float64(2), int64(10), object(4)
# ...

# %%
# Select all the Legendary pokemons

legendary_df = df[df["is_legendary"]==True]

# %%
# Find the outlier. Take a look at the scatterplot that correlates pokemons Attack and Defense. What's the Name of the pokemon that is a clear outlier (strong Defense, but very low Attack).
